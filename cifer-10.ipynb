# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np
import imageio
from glob import glob
import scipy
import scipy.spatial
import pandas as pd
import pickle
import skimage
import skimage.transform

import skimage.util
import skimage.exposure

from skimage.color import rgb2gray
from tqdm import tqdm_notebook as tqdm
from pathlib import Path
import random

# %matplotlib inline

# %%
data_dir = Path("../Datasets/cifar/")

# %%
for p in data_dir.iterdir():
    print(p)
# Out:
# ../Datasets/cifar/学習データcifar.zip
# ../Datasets/cifar/labels.csv
# ../Datasets/cifar/.DS_Store
# ../Datasets/cifar/test
# ../Datasets/cifar/学習データcifar
# ../Datasets/cifar/labels.txt
# ../Datasets/cifar/train

# %%
train_path = data_dir / "train"

# %%
imgs = list(train_path.glob("*.png"))
len(imgs)
# Out:
# 50000

# %%
def get_resize_img(path, dim=28):
    img = imread(path)
    return skimage.transform.resize(img, [dim,dim, 3], mode="reflect")

def get_flatten_img(path, dim=28, invert_gray=False):
    if invert_gray:
        img = 255 - imread(path)
    else:
        img = imread(path)
    return rgb2gray(skimage.transform.resize(img, [dim, dim], mode="reflect"))

def imread(path):
    return imageio.imread(path)

def horizontal_flip(image):
    return image[:, ::-1, :]

def vertical_flip(image): 
    return image[::-1, :]

def rotate_image(image, angle=random.randint(-15, 15)):
    return skimage.transform.rotate(image, angle=angle, resize=False, center=None)

def random_noise(image):
    return skimage.util.random_noise(image)

def invert_color(image):
    return np.invert(image)

def rescale_image(image):
    return skimage.transform.rescale(image, 1.0 / 4.0)

def rescale_intensity(image):
    v_min, v_max = np.percentile(image.astype(np.uint8), (0.2, 99.8))
    return skimage.exposure.rescale_intensity(image.astype(np.uint8), in_range=(v_min, v_max))

def adjust_gamma(image): 
    return skimage.exposure.adjust_gamma(image, gamma=0.4, gain=0.9)

# %%
img = imread("/Users/tdual/Downloads/ponde.jpeg")

# %%
images = [
    img, 
    horizontal_flip(img), 
    rotate_image(img),
    vertical_flip(img), 
    random_noise(img),
    invert_color(img), 
    rescale_intensity(img), 
    adjust_gamma(img)
]

# %%
fig, axs = plt.subplots(2, int(len(images)/2), figsize=(20, 10))
for i, image in enumerate(images):
        if i < len(images)/2:
            y = 0
            x = i
        else:
            y = 1
            x = i - int( len(images)/2)
        axs[y][x].imshow(image)
        axs[y][x].axis('off')
plt.show()

# %%
test = imgs[:10]
fig, axs = plt.subplots(1, len(test), figsize=(20, 3))
for i, path in enumerate(test):
        axs[i].imshow(imread(path))
        axs[i].axis('off')
        label = path.name.split("_")[1]
        axs[i].set_title( label)
plt.show()

# %%
test = imgs[:10]
fig, axs = plt.subplots(1, len(test), figsize=(20, 3))
for i, path in enumerate(test):
        axs[i].imshow(horizontal_flip(imread(path)))
        axs[i].axis('off')
        label = path.name.split("_")[1]
        axs[i].set_title( label)
plt.show()

# %%
imread(imgs[0]).shape
# Out:
# (32, 32, 3)

# %%
def weight_variable(shape):
    w = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(w)


def bias_variable(shape):
    b = tf.constant(0.1, shape=shape)
    return tf.Variable(b)


def conv2d(x, filt, name):
    """
        x is a batch of images. x.shape is [batch_size, in_height, in_width, in_channels]
        filt is a filter. filt.shape is [filter_height, filter_width, in_channels, out_channels]
    """ 
    return tf.nn.conv2d(x, filt, strides=[1,1,1,1], padding='SAME', name=name)


def max_pool(x, name, size=2):
    """
        x is a batch of images. x.shape is [batch_size, in_height, in_width, in_channels]
        size is a pooling size using ksize.
        (ksize is a kernel size. ksize.shape is [batch_size, height, width, channels]
            The batch_size and channels are usual 1 on pooling. If you want 2x2 pooling, ksize=[1, 2, 2, 1])
    
    """
    return tf.nn.max_pool(x, ksize=[1, size, size, 1], strides=[1, 2, 2, 1], padding='SAME', name=name)


def max_pool(x, name, size=2):
    """
        x is a batch of images. x.shape is [batch_size, in_height, in_width, in_channels]
        size is a pooling size using ksize.
        (ksize is a kernel size. ksize.shape is [batch_size, height, width, channels]
            The batch_size and channels are usual 1 on pooling. If you want 2x2 pooling, ksize=[1, 2, 2, 1])
    
    """
    return tf.nn.avg_pool(x, ksize=[1, size, size, 1], strides=[1, 2, 2, 1], padding='SAME', name=name)


def conv_layer(x, out_size, name, filter_size=5, act="relu"):
    shape =x.get_shape().as_list()
    in_channel = shape[-1]
    with tf.name_scope("conv_{}".format(name)):
        with tf.name_scope('weights'):
            W = weight_variable([filter_size, filter_size, in_channel, out_size])
            variable_summaries(W)        
        with tf.name_scope('biases'):
            b = bias_variable([out_size])
            variable_summaries(b)
        h_conv = conv2d(x, W, "conv2d_{}".format(name))
        h = tf.nn.bias_add(h_conv, b)
        variable_summaries(h)
        
    if act == "relu":
        with tf.name_scope("conv_relu_{}".format(name)):
            h_act = tf.nn.relu(h)
    if act == "ident":
        h_act = h
    return h_act


def fc_layer(x_flatten, out_size, name, act="relu"):
    shape =x_flatten.get_shape().as_list()
    dim = shape[1]
    with tf.name_scope("fc_{}".format(name)):
        with tf.name_scope('weights'):
            W = weight_variable([dim, out_size])
        with tf.name_scope('biases'):   
            b  = bias_variable([out_size])
        h = tf.nn.bias_add(tf.matmul(x_flatten, W), b)
      
    if act == "relu":
        with tf.name_scope("fc_relu_{}".format(name)):
            h_act = tf.nn.relu(h)
    if act == "ident":
        h_act = h
    return h_act


def dropout(x, keep_prob, name):
    with tf.name_scope("dropout_{}".format(name)):
        h = tf.nn.dropout(x, keep_prob)
    return h
    

def flatten(x, name):
    shape = x.get_shape().as_list()
    dim = 1
    for s in shape[1:]:
        dim *= s
    with tf.name_scope(name):
        h = tf.reshape(x, [-1, dim])
    return h


def get_channel(x):
    shape = x.get_shape().as_list()
    return shape[-1]

def block(x, out_size, name):
    h_conv_act = conv_layer(x, out_size, name)
    
    with tf.name_scope("pool_{}".format(name)):   
        h_pool1 = max_pool(h_conv_act, name)
        variable_summaries(h_pool1)
    return h_pool1

def vgg_block(x, out_sizes, name):
    """
     x is a batch of images.
     out_sizes is a list of cnn layer sizes.
     name is this function's name. 
    """
    for idx, size in enumerate(out_sizes):
        if idx == 0:
            _x = x
        else:
            _x = h
        h = conv_layer(_x, size, "{}_{}".format(name, idx), filter_size=3)
        
    
    with tf.name_scope("pool_{}".format(name)):   
        h_pool1 = max_pool(h, name)
        variable_summaries(h_pool1)
    return h_pool1


def variable_summaries(var):  
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)

# %%
height = 32
width = 32
channel = 3
image_size = height * width

# %%
g1 = None

# VGG16

with tf.Graph().as_default() as g1:
    keep_prob = tf.placeholder(tf.float32)
    global_step =  tf.placeholder(tf.int32)
    with tf.name_scope('input'):
        x = tf.placeholder(tf.float32, shape=[None, height, width, channel], name='x-input')
        y_ = tf.placeholder(tf.float32, shape=[None, 10], name='y-input')


    h_pool1 = vgg_block(tf.map_fn(lambda frame: tf.image.per_image_standardization(frame), x), [32, 32], "1") # original size: 64
    h_pool2 = vgg_block(h_pool1, [64, 64], "2") # original size: 128
    h_pool3 = vgg_block(h_pool2, [128, 128, 128], "3") # original size: 256
    h_pool4 = vgg_block(h_pool3, [256, 256, 256], "4") # original size: 512
    h_pool5 = vgg_block(h_pool4, [256, 256, 256], "5") # original size: 512
    h_pool_flat = flatten(h_pool5, "pool_flat")
    h_fc1 = fc_layer(h_pool_flat, 1024, "1", act="relu") # original size: 4096
    h_fc1_drop = dropout(h_fc1, keep_prob, "fc1")
    h_fc2 = fc_layer(h_fc1_drop, 1024, "2", act="relu") # original size: 4096
    h_fc2_drop = dropout(h_fc2, keep_prob, "fc2")
    y_conv = fc_layer(h_fc2_drop , 10, "3", act="ident") # original size: 1000
    
    #h_pool1 = block(x, 32, "1")
    #h_pool2 = block(h_pool1, 64, "2")
    #h_pool2_flat = flatten(h_pool2, "pool2_flat")
    #h_fc1 = fc_layer(h_pool2_flat, 1024, "1", act="relu")
    #h_fc1_drop = dropout(h_fc1, keep_prob, "fc1")
    #y_conv = fc_layer(h_fc1_drop , 10, "2", act="ident")

    with tf.name_scope("loss"):
        loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
        tf.summary.scalar('cross_entropy', loss)

    with tf.name_scope("optimizer"):
        starter_learning_rate = 0.01
        #learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,1000, 0.96, staircase=True)
        learning_rate = 1e-4
        opt = tf.train.AdamOptimizer(learning_rate).minimize(loss)

    with tf.name_scope("accuracy"):
        correct = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
        tf.summary.scalar('accuracy', accuracy)

# %%
import tensorboard as tb 
tb.show_graph(g1)
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.5125820183098465&quot;).pbtxt = 'node {\n  name: &quot;Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Placeholder_1&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input/x-input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 32\n        }\n        dim {\n          size: 32\n        }\n        dim {\n          size: 3\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input/y-input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 10\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;map/Shape&quot;\n  op: &quot;Shape&quot;\n  input: &quot;input/x-input&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;map/strided_slice/stack&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;map/strided_slice/stack_1&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;map/strided_slice/stack_2&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 1\n          }\n        }\n        int_val: 1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;map/strided_slice&quot;\n  op: &quot;StridedSlice&quot;\n  input: &quot;map/Shape&quot;\n  input: &quot;map/strided_slice/stack&quot;\n  input: &quot;map/strided_slice/stack_1&quot;\n  input: &quot;map/strided_slice/stack_2&quot;\n  attr {\n    key: &quot;Index&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;begin_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;ellipsis_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;end_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;new_axis_mask&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;shrink_axis_mask&quot;\n    value {\n      i: 1\n    }\n  }\n}\nnode {\n  name: &quot;map/TensorArray&quot;\n  op: &quot;TensorArrayV3&quot;\n  input: &quot;map/strided_slice&quot;\n  attr {\n    key: &quot;clear_after_read&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;dynamic_size& ...

# %%
def get_images(images_path):
    allow_file = ["jpeg","png","jpg","JPEG","JPG","PNG"]
    images = []
    for ext in allow_file:
        images += list(images_path.glob("*."+ext))
    return images


class ImageManager:
    def __init__(self):
        self.test_offset = 0
        self.train_offset = 0
        self.aug_funcs  = [
            horizontal_flip, 
            rotate_image,
            vertical_flip, 
            random_noise,
            invert_color, 
            rescale_intensity, 
            adjust_gamma
        ]

    def imread(self, path):
        return imageio.imread(path)

    def get_resize_gray_img(self, path):
        return rgb2gray(self.get_resize_img(path))

    def get_resize_img(self, path, dim=28, channel=3):
        img = self.imread(path)
        return skimage.transform.resize(img, [dim, dim, channel], mode="reflect")

    def get_flatten_img(self, path, dim=28, invert_gray=False):
        if invert_gray:
            img = 255 - self.imread(path)
        else:
            img = self.imread(path)
        return rgb2gray(skimage.transform.resize(img, [dim, dim], mode="reflect"))

    def load_data(self, path, ratio=0.1):
        p = Path(path)
        labels_path = p / "labels" / "labels.csv"
        self.labels = self.create_label_obj(labels_path)
        image_dir = p / "images"
        images = get_images(image_dir)
        self.n_images = len(images)
        
        print("# of original images: ", self.n_images)
        random.shuffle(images)
        
        print("test/train: ", ratio)
        n_test = int(self.n_images * ratio)
        self.test_images = images[:n_test]
        self.train_images = images[n_test:]
        
        self.n_test = len(self.test_images)
        self.n_train = len(self.train_images)

        print("test/train(original): {}/{} = {:.4}".format(self.n_test, self.n_train, self.n_test/self.n_train))
        

        
        if len(self.aug_funcs) > 0:
            self.train_images = [(img, i)for img in self.train_images for i in range(len(self.aug_funcs))]
            self.n_train = len(self.train_images)
            self.n_image = self.n_test + self.n_train
            print("# of augmented images: ", self.n_image)
            random.shuffle(self.train_images)
            print("test/train(augmented): {}/{} = {:.4}".format(self.n_test, self.n_train, self.n_test/self.n_train))


    

    def create_label_obj(self, path):
        labels = {}
        mapping_dic = {}

        with open(path, "r") as f:
            for line in f:
                filename = line.split(",")[0]
                label = line.split(",")[1][:-1]
                if label in mapping_dic.keys():
                    mapped_label = mapping_dic[label]
                else:
                    length = len(mapping_dic)
                    mapping_dic[label] = length
                    mapped_label = length
                labels[filename] = mapped_label
        self.mapping_dic = mapping_dic
        print(self.mapping_dic)
        return labels

    def next_batch(self, kind, num, one_hot=True):
        if kind == "test":
            
            end = self.test_offset + num
            if end > self.n_test:
                self.test_offset = 0
                end = num
                random.shuffle(self.test_images)
            images = self.test_images
            offset = self.test_offset
            image_paths = images[offset: end]
            label_batch = [np.identity(10)[self.labels[p.name]] for p in image_paths]
            image_batch = [self.imread(str(p)) for p in image_paths]
            
        elif kind == "train":
            end = self.train_offset + num
            if end > self.n_train:
                self.train_offset = 0
                end = num
                random.shuffle(self.train_images)
            images = self.train_images
            offset = self.train_offset
            
            image_paths = images[offset: end]
            label_batch = [np.identity(10)[self.labels[p[0].name]] for p in image_paths]
            image_batch = [self.aug_funcs[p[1]](self.imread(str(p[0]))) for p in image_paths]


        else:
            raise Exception("kind is 'test' or 'train'")

        if kind == "test":
            self.test_offset = end
        elif kind == "train":
            self.train_offset = end
        return label_batch, image_batch

# %%
ima = ImageManager()

# %%
import random
ima.load_data(data_dir/ "学習データcifar", ratio=0.05)
# Out:
# {'deer': 0, 'cat': 1, 'truck': 2, 'automobile': 3, 'bird': 4, 'horse': 5, 'frog': 6, 'ship': 7, 'dog': 8, 'airplane': 9}
# # of original images:  50000
# test/train:  0.05
# test/train(original): 2500/47500 = 0.05263
# # of augmented images:  335000
# test/train(augmented): 2500/332500 = 0.007519

# %%
labels, images = ima.next_batch("train", 10)
fig, axs = plt.subplots(1, len(images), figsize=(20, 3))
for i, image in enumerate(images):
        axs[i].imshow(image)
        axs[i].axis('off')
        axs[i].set_title(np.argmax(labels[i]))
plt.show()

# %%
labels, images = ima.next_batch("test", 10)
fig, axs = plt.subplots(1, len(images), figsize=(20, 3))
for i, image in enumerate(images):
        axs[i].imshow(image)
        axs[i].axis('off')
        axs[i].set_title(np.argmax(labels[i]))
plt.show()

# %%
image.shape
# Out:
# (32, 32, 3)

# %%
images_std = [tf.image.per_image_standardization(img) for img in images]

# %%
ima.n_train
batch_size = 100
batch_per_epoch = int(ima.n_train / batch_size)
batch_per_epoch
# Out:
# 3325

# %%
n_epoch = 20

# %%
n_iter = batch_per_epoch * n_epoch
print(n_iter)
# Out:
# 66500

# %%
log_dir= "logs"
if tf.gfile.Exists(log_dir):
    tf.gfile.DeleteRecursively(log_dir)
tf.gfile.MakeDirs(log_dir)



with tf.Session(graph=g1) as sess:
    sess.run(tf.global_variables_initializer())
    
    merged = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
    test_writer = tf.summary.FileWriter(log_dir + '/test')
    
    for i in tqdm(range(n_iter)):
        labels, images = ima.next_batch("train", batch_size)
        _ = sess.run(opt, feed_dict={x: images, y_:  labels, keep_prob: 0.6, global_step: i})
        
        
        if i % 100 == 0 and i !=0:
            train_loss, train_accuracy, summary = sess.run([loss, accuracy, merged], feed_dict={x: images, y_: labels, keep_prob: 0.6})
            print('step %d, training loss %g, training accuracy %g' % (i, train_loss, train_accuracy))
            train_writer.add_summary(summary, i)
            
        if i % 500 == 0 and i !=0:
            labels, images = ima.next_batch("test", batch_size)
            test_loss, test_accuracy, test_summary, = sess.run([loss, accuracy, merged], feed_dict={x: images, y_: labels, keep_prob: 1.0})
            test_writer.add_summary(test_summary, 0)
            print('\nstep %d, test loss %g, test accuracy %g\n' % (i, test_loss, test_accuracy))
# Out:
# HBox(children=(IntProgress(value=0, max=66500), HTML(value='')))
# step 100, training loss 18.5155, training accuracy 0.11
# step 200, training loss 10.7436, training accuracy 0.08
# step 300, training loss 5.79144, training accuracy 0.16
# step 400, training loss 3.96579, training accuracy 0.11
# step 500, training loss 2.90005, training accuracy 0.12
#
# step 500, test loss 2.32196, test accuracy 0.15
#
# step 600, training loss 2.49422, training accuracy 0.16
# step 700, training loss 2.38838, training accuracy 0.12
# step 800, training loss 2.41182, training accuracy 0.12
# step 900, training loss 2.36277, training accuracy 0.16
# step 1000, training loss 2.27861, training accuracy 0.14
#
# step 1000, test loss 2.21569, test accuracy 0.17
#
# step 1100, training loss 2.29177, training accuracy 0.14
# step 1200, training loss 2.2192, training accuracy 0.17
# step 1300, training loss 2.2476, training accuracy 0.15
# step 1400, training loss 2.31978, training accuracy 0.17
# step 1500, training loss 2.12497, training accuracy 0.25
#
# step 1500, test loss 2.04304, test accuracy 0.23
#
# step 1600, training loss 2.10777, training accuracy 0.2
# step 1700, training loss 2.17317, training accuracy 0.2
# step 1800, training loss 2.12711, training accuracy 0.18
# step 1900, training loss 2.27155, training accuracy 0.16
# step 2000, training loss 2.22342, training accuracy 0.16
#
# step 2000, test loss 1.94108, test accuracy 0.21
#
# step 2100, training loss 2.15469, training accuracy 0.17
# step 2200, training loss 1.85396, training accuracy 0.3
# step 2300, training loss 2.07673, training accuracy 0.19
# step 2400, training loss 2.13086, training accuracy 0.23
# step 2500, training loss 2.06412, training accuracy 0.24
#
# step 2500, test loss 1.90928, test accuracy 0.26
#
# step 2600, training loss 2.08206, training accuracy 0.14
# step 2700, training loss 1.91946, training accuracy 0.28
# step 2800, training loss 1.89643, training accuracy 0.33
# step 2900, training loss 1.83115, training accuracy 0.28
# step 3000, training loss 1.95636, training accuracy 0.35
#
# step 3000, test loss 1.66057, test accuracy 0.48
#
# step 3100, training loss 1.97161, training accuracy 0.24
# step 3200, training loss 2.03095, training accuracy 0.29
# step 3300, training loss 2.05552, training accuracy 0.23
# step 3400, training loss 1.9352, training accuracy 0.28
# step 3500, training loss 1.92193, training accuracy 0.3
#
# step 3500, test loss 1.81445, test accuracy 0.28
#
# step 3600, training loss 1.84032, training accuracy 0.27
# step 3700, training loss 1.96406, training accuracy 0.35
# step 3800, training loss 1.92925, training accuracy 0.24
# step 3900, training loss 1.6988, training accuracy 0.38
# step 4000, training loss 1.99333, training accuracy 0.3
#
# step 4000, test loss 1.6861, test accuracy 0.38
#
# step 4100, training loss 1.58374, training accuracy 0.45
# step 4200, training loss 1.80753, training accuracy 0.3
# step 4300, training loss 1.75597, training accuracy 0.3
# step 4400, training loss 1.71678, training accuracy 0.31
# step 4500, training loss 1.90372, training accuracy 0.32
#
# step 4500, test loss 1.69132, test accuracy 0.43
#
# step 4600, training loss 1.70658, training accuracy 0.41
# step 4700, training loss 1.80038, training accuracy 0.32
# step 4800, training loss 1.65099, training accuracy 0.33
# step 4900, training loss 1.77861, training accuracy 0.33
# step 5000, training loss 1.82529, training accuracy 0.29
#
# step 5000, test loss 1.57677, test accuracy 0.39
#
# step 5100, training loss 1.90751, training accuracy 0.26
# step 5200, training loss 1.81702, training accuracy 0.33
# step 5300, training loss 1.7365, training accuracy 0.39
# step 5400, training loss 1.96075, training accuracy 0.27
# step 5500, training loss 1.7842, training accuracy 0.33
#
# step 5500, test loss 1.67251, test accuracy 0.45
#
# step 5600, training loss 1.92321, training accuracy 0.23
# step 5700, training loss 1.71664, training accuracy 0.41
# step 5800, training loss 1.62853, training accuracy 0.42
# step 5900, training loss 1.68632, training accuracy 0.33
# step 6000, training loss 1.6682, training accuracy 0.4
#
# step 6000, test loss 1.62523, test accuracy 0.42
#
# step 6100, training loss 1.63471, training accuracy 0.37
# step 6200, training loss 1.56349, training accuracy 0.41
# step 6300, training loss 1.63358, training accuracy 0.45
# step 6400, training loss 1.6853, training accuracy 0.36
# step 6500, training loss 1.70621, training accuracy 0.35
#
# step 6500, test loss 1.52829, test accuracy 0.42
#
# step 6600, training loss 1.4633, training accuracy 0.47
# step 6700, training loss 1.56162, training accuracy 0.37
# step 6800, training loss 1.40502, training accuracy 0.47
# step 6900, training loss 1.59001, training accuracy 0.42
# step 7000, training loss 1.56618, training accuracy 0.39
#
# step 7000, test loss 1.33461, test accuracy 0.52
#
# step 7100, training loss 1.60708, training accuracy 0.39
# step 7200, training loss 1.4109, training accuracy 0.44
# step 7300, training loss 1.53244, training accuracy 0.46
# step 7400, training loss 1.56589, training accuracy 0.45
# step 7500, training loss 1.5323, training accuracy 0.5
#
# step 7500, test loss 1.44472, test accuracy 0.5
#
# step 7600, training loss 1.50782, training accuracy 0.43
# step 7700, training loss 1.43988, training accuracy 0.47
# step 7800, training loss 1.38782, training accuracy 0.5
# step 7900, training loss 1.50022, training accuracy 0.5
# step 8000, training loss 1.35639, training accuracy 0.54
#
# step 8000, test loss 1.38203, test accuracy 0.57
#
# step 8100, training loss 1.37546, training accuracy 0.52
# step 8200, training loss 1.48832, training accuracy 0.45
# step 8300, training loss 1.34395, training accuracy 0.51
# step 8400, training loss 1.43433, training accuracy 0.47
# step 8500, training loss 1.46943, training accuracy 0.49
#
# step 8500, test loss 1.37341, test accuracy 0.53
#
# step 8600, training loss 1.28252, training accuracy 0.5
# step 8700, training loss 1.64752, training accuracy 0.49
# step 8800, training loss 1.44261, training accuracy 0.48
# step 8900, training loss 1.344, training accuracy 0.51
# step 9000, training loss 1.23492, training accuracy 0.58
#
# step 9000, test loss 1.20391, test accuracy 0.59
#
# step 9100, training loss 1.31394, training accuracy 0.53
# step 9200, training loss 1.32776, training accuracy 0.48
# step 9300, training loss 1.33039, training accuracy 0.54
# step 9400, training loss 1.22461, training accuracy 0.55
# step 9500, training loss 1.3133, training accuracy 0.51
#
# step 9500, test loss 1.31822, test accuracy 0.55
#
# step 9600, training loss 1.39539, training accuracy 0.52
# step 9700, training loss 1.32009, training accuracy 0.55
# step 9800, training loss 1.32587, training accuracy 0.53
# step 9900, training loss 1.18729, training accuracy 0.55
# step 10000, training loss 1.38321, training accuracy 0.48
#
# step 10000, test loss 1.31437, test accuracy 0.55
#
# step 10100, training loss 1.38714, training accuracy 0.51
# step 10200, training loss 1.36197, training accuracy 0.48
# step 10300, training loss 1.36537, training accuracy 0.47
# step 10400, training loss 1.11757, training accuracy 0.6
# step 10500, training loss 1.2494, training accuracy 0.6
#
# step 10500, test loss 1.22907, test accuracy 0.57
#
# step 10600, training loss 1.13584, training accuracy 0.54
# step 10700, training loss 1.30465, training accuracy 0.52
# step 10800, training loss 1.00023, training accuracy 0.6
# step 10900, training loss 1.2994, training accuracy 0.57
# step 11000, training loss 1.14583, training accuracy 0.61
#
# step 11000, test loss 1.13697, test accuracy 0.62
#
# step 11100, training loss 1.18451, training accuracy 0.56
# step 11200, training loss 1.26908, training accuracy 0.59
# step 11300, training loss 1.34281, training accuracy 0.55
# step 11400, training loss 1.16466, training accuracy 0.59
# step 11500, training loss 1.08592, training accuracy 0.54
#
# step 11500, test loss 1.15449, test accuracy 0.61
#
# step 11600, training loss 1.22315, training accuracy 0.59
# step 11700, training loss 1.29495, training accuracy 0.61
# step 11800, training loss 1.25074, training accuracy 0.52
# step 11900, training loss 1.31196, training accuracy 0.55
# step 12000, training loss 1.2228, training accuracy 0.57
#
# step 12000, test loss 1.0961, test accuracy 0.67
#
# step 12100, training loss 1.26065, training accuracy 0.61
# step 12200, training loss 1.17663, training accuracy 0.56
# step 12300, training loss 1.26059, training accuracy 0.47
# step 12400, training loss 1.15694, training accuracy 0.59
# step 12500, training loss 1.36106, training accuracy 0.48
#
# step 12500, test loss 0.853786, test accuracy 0.73
#
# step 12600, training loss 1.05545, training accuracy 0.59
# step 12700, training loss 1.30351, training accuracy 0.55
# step 12800, training loss 1.04645, training accuracy 0.65
# step 12900, training loss 1.12667, training accuracy 0.61
# step 13000, training loss 1.14502, training accuracy 0.58
#
# step 13000, test loss 1.04803, test accuracy 0.57
#
# step 13100, training loss 1.21944, training accuracy 0.62
# step 13200, training loss 1.08248, training accuracy 0.62
# step 13300, training loss 1.011, training accuracy 0.65
# step 13400, training loss 1.02346, training accuracy 0.65
# step 13500, training loss 0.912758, training accuracy 0.7
#
# step 13500, test loss 0.981549, test accuracy 0.68
#
# step 13600, training loss 0.868085, training accuracy 0.66
# step 13700, training loss 1.37636, training accuracy 0.51
# step 13800, training loss 0.949383, training accuracy 0.68
# step 13900, training loss 0.832092, training accuracy 0.74
# step 14000, training loss 0.941325, training accuracy 0.69
#
# step 14000, test loss 1.15141, test accuracy 0.65
#
# step 14100, training loss 1.11173, training accuracy 0.7
# step 14200, training loss 1.06876, training accuracy 0.66
# step 14300, training loss 1.12626, training accuracy 0.61
# step 14400, training loss 0.948367, training accuracy 0.63
# step 14500, training loss 1.04556, training accuracy 0.59
#
# step 14500, test loss 0.921682, test accuracy 0.73
#
# step 14600, training loss 1.24128, training accuracy 0.53
# step 14700, training loss 0.76071, training accuracy 0.77
# step 14800, training loss 1.25387, training accuracy 0.61
# step 14900, training loss 1.0306, training accuracy 0.7
# step 15000, training loss 1.05913, training accuracy 0.66
#
# step 15000, test loss 0.953508, test accuracy 0.69
#
# step 15100, training loss 1.05972, training accuracy 0.68
# step 15200, training loss 1.20313, training accuracy 0.61
# step 15300, training loss 0.877887, training accuracy 0.73
# step 15400, training loss 1.01568, training accuracy 0.63
# step 15500, training loss 0.871829, training accuracy 0.71
#
# step 15500, test loss 0.917205, test accuracy 0.69
#
# step 15600, training loss 0.924723, training accuracy 0.7
# step 15700, training loss 0.897112, training accuracy 0.7
# step 15800, training loss 1.03375, training accuracy 0.66
# step 15900, training loss 0.998014, training accuracy 0.67
# step 16000, training loss 1.02568, training accuracy 0.67
#
# step 16000, test loss 0.812188, test accuracy 0.73
#
# step 16100, training loss 0.837369, training accuracy 0.72
# step 16200, training loss 0.839372, training accuracy 0.7
# step 16300, training loss 1.1278, training accuracy 0.63
# step 16400, training loss 0.908412, training accuracy 0.67
# step 16500, training loss 0.887816, training accuracy 0.66
#
# step 16500, test loss 0.72549, test accuracy 0.72
#
# step 16600, training loss 0.867789, training accuracy 0.69
# step 16700, training loss 0.963173, training accuracy 0.62
# step 16800, training loss 0.941188, training accuracy 0.66
# step 16900, training loss 1.03297, training accuracy 0.66
# step 17000, training loss 0.813573, training accuracy 0.69
#
# step 17000, test loss 0.745676, test accuracy 0.72
#
# step 17100, training loss 0.881903, training accuracy 0.69
# step 17200, training loss 0.858642, training accuracy 0.66
# step 17300, training loss 0.916312, training accuracy 0.74
# step 17400, training loss 0.872007, training accuracy 0.67
# step 17500, training loss 1.08114, training accuracy 0.65
#
# step 17500, test loss 0.993416, test accuracy 0.65
#
# step 17600, training loss 0.749536, training accuracy 0.76
# step 17700, training loss 0.678771, training accuracy 0.81
# step 17800, training loss 0.749089, training accuracy 0.76
# step 17900, training loss 0.856722, training accuracy 0.76
# step 18000, training loss 0.914637, training accuracy 0.62
#
# step 18000, test loss 0.897182, test accuracy 0.67
#
# step 18100, training loss 0.755003, training accuracy 0.75
# step 18200, training loss 0.71455, training accuracy 0.76
# step 18300, training loss 0.994771, training accuracy 0.71
# step 18400, training loss 0.845286, training accuracy 0.7
# step 18500, training loss 0.730599, training accuracy 0.75
#
# step 18500, test loss 0.882047, test accuracy 0.67
#
# step 18600, training loss 0.823432, training accuracy 0.76
# step 18700, training loss 0.987555, training accuracy 0.68
# step 18800, training loss 0.865446, training accuracy 0.73
# step 18900, training loss 0.686608, training accuracy 0.73
# step 19000, training loss 0.987028, training accuracy 0.64
#
# step 19000, test loss 0.684759, test accuracy 0.71
#
# step 19100, training loss 0.685415, training accuracy 0.75
# step 19200, training loss 0.752938, training accuracy 0.74
# step 19300, training loss 0.913853, training accuracy 0.67
# step 19400, training loss 0.813106, training accuracy 0.75
# step 19500, training loss 0.873574, training accuracy 0.62
#
# step 19500, test loss 0.898996, test accuracy 0.75
#
# step 19600, training loss 0.630958, training accuracy 0.78
# step 19700, training loss 0.797195, training accuracy 0.7
# step 19800, training loss 0.735256, training accuracy 0.71
# step 19900, training loss 0.574664, training accuracy 0.79
# step 20000, training loss 0.795349, training accuracy 0.71
#
# step 20000, test loss 0.721688, test accuracy 0.77
#
# step 20100, training loss 0.648857, training accuracy 0.79
# step 20200, training loss 0.856912, training accuracy 0.7
# step 20300, training loss 0.736526, training accuracy 0.76
# step 20400, training loss 0.881115, training accuracy 0.74
# step 20500, training loss 0.644194, training accuracy 0.78
#
# step 20500, test loss 0.741605, test accuracy 0.73
#
# step 20600, training loss 0.730151, training accuracy 0.77
# step 20700, training loss 0.6707, training accuracy 0.78
# step 20800, training loss 0.707259, training accuracy 0.79
# step 20900, training loss 0.796276, training accuracy 0.75
# step 21000, training loss 0.799103, training accuracy 0.71
#
# step 21000, test loss 0.96325, test accuracy 0.67
#
# step 21100, training loss 0.720846, training accuracy 0.74
# step 21200, training loss 0.763107, training accuracy 0.8
# step 21300, training loss 0.665304, training accuracy 0.75
# step 21400, training loss 0.81164, training accuracy 0.77
# step 21500, training loss 0.632627, training accuracy 0.82
#
# step 21500, test loss 0.702577, test accuracy 0.79
#
# step 21600, training loss 0.710885, training accuracy 0.7
# step 21700, training loss 0.63293, training accuracy 0.78
# step 21800, training loss 0.602462, training accuracy 0.82
# step 21900, training loss 0.767109, training accuracy 0.72
# step 22000, training loss 0.721736, training accuracy 0.76
#
# step 22000, test loss 0.832715, test accuracy 0.72
#
# step 22100, training loss 0.707447, training accuracy 0.75
# step 22200, training loss 0.700918, training accuracy 0.77
# step 22300, training loss 0.712481, training accuracy 0.74
# step 22400, training loss 0.557262, training accuracy 0.82
# step 22500, training loss 0.786983, training accuracy 0.71
#
# step 22500, test loss 0.803662, test accuracy 0.69
#
# step 22600, training loss 0.856077, training accuracy 0.71
# step 22700, training loss 0.77933, training accuracy 0.71
# step 22800, training loss 0.634916, training accuracy 0.78
# step 22900, training loss 0.645658, training accuracy 0.78
# step 23000, training loss 0.790096, training accuracy 0.77
#
# step 23000, test loss 0.768797, test accuracy 0.68
#
# step 23100, training loss 0.663463, training accuracy 0.79
# step 23200, training loss 0.776682, training accuracy 0.73
# step 23300, training loss 0.456364, training accuracy 0.83
# step 23400, training loss 0.431971, training accuracy 0.84
# step 23500, training loss 0.654456, training accuracy 0.75
#
# step 23500, test loss 0.605228, test accuracy 0.78
#
# step 23600, training loss 0.570461, training accuracy 0.8
# step 23700, training loss 0.446902, training accuracy 0.86
# step 23800, training loss 0.490745, training accuracy 0.86
# step 23900, training loss 0.807664, training accuracy 0.73
# step 24000, training loss 0.501452, training accuracy 0.82
#
# step 24000, test loss 0.799751, test accuracy 0.73
#
# step 24100, training loss 0.725791, training accuracy 0.74
# step 24200, training loss 0.488737, training accuracy 0.83
# step 24300, training loss 0.619262, training accuracy 0.75
# step 24400, training loss 0.646374, training accuracy 0.76
# step 24500, training loss 0.492402, training accuracy 0.81
#
# step 24500, test loss 0.91968, test accuracy 0.64
#
# step 24600, training loss 0.526746, training accuracy 0.8
# step 24700, training loss 0.498497, training accuracy 0.83
# step 24800, training loss 0.660848, training accuracy 0.76
# step 24900, training loss 0.494721, training accuracy 0.83
# step 25000, training loss 0.668147, training accuracy 0.77
#
# step 25000, test loss 0.694916, test accuracy 0.78
#
# step 25100, training loss 0.744431, training accuracy 0.73
# step 25200, training loss 0.539369, training accuracy 0.75
# step 25300, training loss 0.48223, training accuracy 0.86
# step 25400, training loss 0.611899, training accuracy 0.75
# step 25500, training loss 0.458024, training accuracy 0.85
#
# step 25500, test loss 0.650229, test accuracy 0.73
#
# step 25600, training loss 0.645486, training accuracy 0.77
# step 25700, training loss 0.665481, training accuracy 0.78
# step 25800, training loss 0.5536, training accuracy 0.81
# step 25900, training loss 0.44017, training accuracy 0.87
# step 26000, training loss 0.489332, training accuracy 0.81
#
# step 26000, test loss 0.888721, test accuracy 0.7
#
# step 26100, training loss 0.560133, training accuracy 0.8
# step 26200, training loss 0.563554, training accuracy 0.84
# step 26300, training loss 0.585238, training accuracy 0.79
# step 26400, training loss 0.511483, training accuracy 0.86
# step 26500, training loss 0.737438, training accuracy 0.74
#
# step 26500, test loss 1.06066, test accuracy 0.63
#
# step 26600, training loss 0.461609, training accuracy 0.89
# step 26700, training loss 0.500407, training accuracy 0.8
# step 26800, training loss 0.40175, training accuracy 0.89
# step 26900, training loss 0.396907, training accuracy 0.84
# step 27000, training loss 0.525515, training accuracy 0.82
#
# step 27000, test loss 0.630712, test accuracy 0.79
#
# step 27100, training loss 0.489579, training accuracy 0.83
# step 27200, training loss 0.378884, training accuracy 0.88
# step 27300, training loss 0.415625, training accuracy 0.85
# step 27400, training loss 0.466525, training accuracy 0.85
# step 27500, training loss 0.563611, training accuracy 0.8
#
# step 27500, test loss 1.08651, test accuracy 0.66
#
# step 27600, training loss 0.534728, training accuracy 0.81
# step 27700, training loss 0.652992, training accuracy 0.77
# step 27800, training loss 0.51749, training accuracy 0.85
# step 27900, training loss 0.448091, training accuracy 0.85
# step 28000, training loss 0.443915, training accuracy 0.82
#
# step 28000, test loss 0.627912, test accuracy 0.78
#
# step 28100, training loss 0.553495, training accuracy 0.82
# step 28200, training loss 0.497468, training accuracy 0.82
# step 28300, training loss 0.39583, training accuracy 0.88
# step 28400, training loss 0.483041, training accuracy 0.85
# step 28500, training loss 0.416311, training accuracy 0.87
#
# step 28500, test loss 0.698999, test accuracy 0.8
#
# step 28600, training loss 0.573137, training accuracy 0.78
# step 28700, training loss 0.699725, training accuracy 0.76
# step 28800, training loss 0.349954, training accuracy 0.86
# step 28900, training loss 0.426198, training accuracy 0.84
# step 29000, training loss 0.719842, training accuracy 0.76
#
# step 29000, test loss 0.657805, test accuracy 0.8
#
# step 29100, training loss 0.39843, training accuracy 0.89
# step 29200, training loss 0.390048, training accuracy 0.87
# step 29300, training loss 0.326375, training accuracy 0.91
# step 29400, training loss 0.455018, training accuracy 0.87
# step 29500, training loss 0.46977, training accuracy 0.85
#
# step 29500, test loss 0.634754, test accuracy 0.77
#
# step 29600, training loss 0.485775, training accuracy 0.8
# step 29700, training loss 0.501584, training accuracy 0.82
# step 29800, training loss 0.479102, training accuracy 0.83
# step 29900, training loss 0.513236, training accuracy 0.81
# step 30000, training loss 0.289095, training accuracy 0.92
#
# step 30000, test loss 0.763595, test accuracy 0.74
#
# step 30100, training loss 0.405607, training accuracy 0.9
# step 30200, training loss 0.398603, training accuracy 0.87
# step 30300, training loss 0.482207, training accuracy 0.82
# step 30400, training loss 0.462315, training accuracy 0.85
# step 30500, training loss 0.281288, training accuracy 0.93
#
# step 30500, test loss 0.837201, test accuracy 0.73
#
# step 30600, training loss 0.312343, training accuracy 0.9
# step 30700, training loss 0.491407, training accuracy 0.85
# step 30800, training loss 0.432295, training accuracy 0.88
# step 30900, training loss 0.453721, training accuracy 0.84
# step 31000, training loss 0.385937, training accuracy 0.89
#
# step 31000, test loss 0.941994, test accuracy 0.72
#
# step 31100, training loss 0.372806, training accuracy 0.88
# step 31200, training loss 0.38124, training accuracy 0.89
# step 31300, training loss 0.363041, training accuracy 0.85
# step 31400, training loss 0.470646, training accuracy 0.83
# step 31500, training loss 0.34331, training accuracy 0.87
#
# step 31500, test loss 1.01187, test accuracy 0.66
#
# step 31600, training loss 0.415307, training accuracy 0.87
# -------------------------------------------------------------
# KeyboardInterrupt           Traceback (most recent call last)
# <ipython-input-80-19abab59ca8d> in <module>()
#      15     for i in tqdm(range(n_iter)):
#      16         labels, images = ima.next_batch("train", batch_size)
# ---> 17         _ = sess.run(opt, feed_dict={x: images, y_:  labels, keep_prob: 0.6, global_step: i})
#      18
#      19
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
# create labels.csv

# %%
imgs[0].name.split("_")[1].split(".")[0]

# %%
tpl_list = [(p.name, p.name.split("_")[1].split(".")[0]) for p in tqdm(imgs)]

# %%
len(tpl_list)

# %%
tpl_list[:2]

# %%
df = pd.DataFrame(tpl_list, columns=["filename", "label"])
df = df.set_index("filename")
df.head()

# %%
df.to_csv("../Datasets/cifar/labels.csv", header=False)

# %%
for i,j in zip([1,2,3,4,5],["A","B","c"]):
    print(i,j)

# %%
[(i,j) for i in ["A","B","C"] for j in range(10)]
