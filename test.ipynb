# %% [markdown]
# downlaod from fashion MNIST
# ```
# wget http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# wget http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# wget http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# wget http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# ```
# put them into data/fashion

# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy import misc
from tqdm import tqdm_notebook as tqdm
# %matplotlib inline

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('./data/fashion', one_hot=True)
# Out:
# Extracting ./data/fashion/train-images-idx3-ubyte.gz
# Extracting ./data/fashion/train-labels-idx1-ubyte.gz
# Extracting ./data/fashion/t10k-images-idx3-ubyte.gz
# Extracting ./data/fashion/t10k-labels-idx1-ubyte.gz

# %%
img, label = mnist.train.next_batch(10)

# %%
dim = 28
fig, axs = plt.subplots(1, len(img), figsize=(20, 3))
for i, m in enumerate(img):
        axs[i].imshow(np.reshape(m, (dim, dim)),cmap='gray')
        axs[i].axis('off')
plt.show()

# %%
def weight_variable(shape):
    w = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(w)

def bias_variable(shape):
    b = tf.constant(0.1, shape=shape)
    return tf.Variable(b)

def conv2d(x, filt):
    """
    x is a batch of images. x.shape is [batch_size, in_height, in_width, in_channels]
    filt is a filter. W.shape is [filter_height, filter_width, in_channels, out_channels]
    """
    return tf.nn.conv2d(x, W, strides=[1,1,1,1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

def batch_normalization(x):
    """
      x -> γ(x-μ)/√（σ^2-ε）　+ β
      
      γ : scale
      μ: mean (first moment)
      σ: variance (second moment)
      β: offset
      ε: to avoid dividing by 0
    """
    epsilon = 1e-8
    dim = x.get_shape()[-1]
    scale = tf.Variable(tf.ones([dim]))
    offset = tf.Variable(tf.zeros([dim]))
    mean, variance = tf.nn.moments(x, [0,1,2])
    return tf.nn.batch_normalization(x, mean, variance, offset, scale, epsilon)

def variable_summaries(var):  
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)

# %%
img, label = mnist.train.next_batch(100)

x = tf.placeholder(tf.float32, shape=[None, 28*28], name='x-input')
x_img= tf.reshape(x, [-1, 28, 28, 1])

W_conv = weight_variable([5,5,1,32])

h_conv = tf.nn.conv2d(x_img, W_conv, strides=[1,1,1,1], padding='SAME')

b_conv = bias_variable([32])

h = h_conv + b_conv
d =  h.get_shape()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    r = sess.run(d, feed_dict={x: img})
r
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in __init__(self, fetches, contraction_fn)
#     269         self._unique_fetches.append(ops.get_default_graph().as_graph_element(
# --> 270             fetch, allow_tensor=True, allow_operation=True))
#     271       except TypeError as e:
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in as_graph_element(self, obj, allow_tensor, allow_operation)
#    2707     with self._lock:
# -> 2708       return self._as_graph_element_locked(obj, allow_tensor, allow_operation)
#    2709
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _as_graph_element_locked(self, obj, allow_tensor, allow_operation)
#    2796       raise TypeError("Can not convert a %s into a %s."
# -> 2797                       % (type(obj).__name__, types_str))
#    2798
#
# TypeError: Can not convert a TensorShape into a Tensor or Operation.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-b22ad347ca26> in <module>()
#      15 with tf.Session() as sess:
#      16     sess.run(tf.global_variables_initializer())
# ---> 17     r = sess.run(d, feed_dict={x: img})
#      18 r
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1107     # Create a fetch handler to take care of the structure of fetches.
#    1108     fetch_handler = _FetchHandler(
# -> 1109         self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1110
#    1111     # Run request and get response.
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in __init__(self, graph, fetches, feeds, feed_handles)
#     411     """
#     412     with graph.as_default():
# --> 413       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     414     self._fetches = []
#     415     self._targets = []
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in for_fetch(fetch)
#     239         if isinstance(fetch, tensor_type):
#     240           fetches, contraction_fn = fetch_fn(fetch)
# --> 241           return _ElementFetchMapper(fetches, contraction_fn)
#     242     # Did not find anything.
#     243     raise TypeError('Fetch argument %r has invalid type %r' %
#
# ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in __init__(self, fetches, contraction_fn)
#     272         raise TypeError('Fetch argument %r has invalid type %r, '
#     273                         'must be a string or Tensor. (%s)'
# --> 274                         % (fetch, type(fetch), str(e)))
#     275       except ValueError as e:
#     276         raise ValueError('Fetch argument %r cannot be interpreted as a '
#
# TypeError: Fetch argument TensorShape([Dimension(None), Dimension(28), Dimension(28), Dimension(32)]) has invalid type <class 'tensorflow.python.framework.tensor_shape.TensorShape'>, must be a string or Tensor. (Can not convert a TensorShape into a Tensor or Operation.)

# %%
tf.shape??
# Out:
# Signature: tf.shape(input, name=None, out_type=tf.int32)
# Source:
# def shape(input, name=None, out_type=dtypes.int32):
#   # pylint: disable=redefined-builtin
#   """Returns the shape of a tensor.
#
#   This operation returns a 1-D integer tensor representing the shape of `input`.
#
#   For example:
#
#   ```python
#   # 't' is [[[1, 1, 1], [2, 2, 2]], [[3, 3, 3], [4, 4, 4]]]
#   shape(t) ==> [2, 2, 3]
#   ```
#
#   Args:
#     input: A `Tensor` or `SparseTensor`.
#     name: A name for the operation (optional).
#     out_type: (Optional) The specified output type of the operation
#       (`int32` or `int64`). Defaults to `tf.int32`.
#
#   Returns:
#     A `Tensor` of type `out_type`.
#   """
#   return shape_internal(input, name, optimize=True, out_type=out_type)
# File:      ~/anaconda2/envs/py3.6/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py
# Type:      function

# %%
def build_graph(bn=True):
    height = 28
    width = 28
    image_size = height * width

    tf.reset_default_graph()
    with tf.Graph().as_default() as g1:
        with tf.name_scope('input'):
            x = tf.placeholder(tf.float32, shape=[None, image_size], name='x-input')
            y_ = tf.placeholder(tf.float32, shape=[None, 10], name='y-input')
            keep_prob = tf.placeholder(tf.float32, name="dropout-input")

        with tf.name_scope('input_reshape'):    
            x_image = tf.reshape(x, [-1, height, width, 1])
            tf.summary.image('input',  x_image, 10)

        with tf.name_scope("conv1"):
            with tf.name_scope('weights'):
                W_conv1 = weight_variable([5,5,1,32])
                variable_summaries(W_conv1)        
            with tf.name_scope('biases'):
                b_conv1 = bias_variable([32])
                variable_summaries(b_conv1)
            h_conv1 = conv2d(x_image, W_conv1) + b_conv1
            variable_summaries(h_conv1)
        
        if bn:
            with tf.name_scope("batch_norm1"):
                h_conv1_bn = batch_normalization(h_conv1)
        else:
                h_conv1_bn = h_conv1
            
        with tf.name_scope("relu1"):
            h_conv1_act = tf.nn.relu(h_conv1_bn)

        with tf.name_scope("pool1"):   
            h_pool1 = max_pool_2x2(h_conv1_act)
            variable_summaries(h_pool1)

        with tf.name_scope("conv2"):
            with tf.name_scope('weights'):
                W_conv2 = weight_variable([5,5,32,64])
                variable_summaries(W_conv2) 
            with tf.name_scope('biases'):    
                b_conv2 = bias_variable([64])
                variable_summaries(b_conv2)
            h_conv2 = conv2d(h_pool1, W_conv2) + b_conv2
            variable_summaries(h_conv2)
        
        if bn:
            with tf.name_scope("batch_norm2"):
                h_conv2_bn = batch_normalization(h_conv2)
        else:
                h_conv2_bn = h_conv2

        with tf.name_scope("relu2"):
            h_conv2_act = tf.nn.relu(h_conv2_bn)

        with tf.name_scope("pool2"):
            h_pool2 = max_pool_2x2(h_conv2_act)
            variable_summaries(h_pool2)

        with tf.name_scope("pool2_flat"):
            h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])

        with tf.name_scope("fc1"):
            with tf.name_scope('weights'):
                W_fc1 = weight_variable([7 * 7 * 64, 1024])
            with tf.name_scope('biases'):   
                b_fc1 = bias_variable([1024])
            h_fc1 =tf.matmul(h_pool2_flat, W_fc1) + b_fc1

        with tf.name_scope("relu3"):
            h_fc1_act = tf.nn.relu(h_fc1)

        with tf.name_scope("dropout"):
            h_fc1_drop = tf.nn.dropout(h_fc1_act, keep_prob)

        with tf.name_scope("fc2"):
            with tf.name_scope('weights'):
                W_fc2 = weight_variable([1024,10])
            with tf.name_scope('biases'): 
                b_fc2 = bias_variable([10]) 
            y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

        with tf.name_scope("loss"):
            loss = tf.reduce_mean(
                tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
            tf.summary.scalar('cross_entropy', loss)
     
        with tf.name_scope("optimizer_1"):
                opt = tf.train.AdamOptimizer(1e-3).minimize(loss)

        with tf.name_scope("accuracy"):
            correct = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
            accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
            tf.summary.scalar('accuracy', accuracy)
    
    res = {
        "g": g1,
        "x": x,
        "y": y_,
        "keep_prob": keep_prob,
        "loss": loss,
        "acc": accuracy,
        "opt": opt
    }
    return res

# %%
g = build_graph(True)["g"]
import tensorboard as tb 
tb.show_graph(g)
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.3768127730124099&quot;).pbtxt = 'node {\n  name: &quot;input/x-input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 784\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input/y-input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 10\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input/dropout-input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input_reshape/Reshape/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\377\\377\\377\\377\\034\\000\\000\\000\\034\\000\\000\\000\\001\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input_reshape/Reshape&quot;\n  op: &quot;Reshape&quot;\n  input: &quot;input/x-input&quot;\n  input: &quot;input_reshape/Reshape/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;Tshape&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;input_reshape/input/tag&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_STRING\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_STRING\n        tensor_shape {\n        }\n        string_val: &quot;input_reshape/input&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input_reshape/input&quot;\n  op: &quot;ImageSummary&quot;\n  input: &quot;input_reshape/input/tag&quot;\n  input: &quot;input_reshape/Reshape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;bad_color&quot;\n    value {\n      tensor {\n        dtype: DT_UINT8\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        int_val: 255\n        int_val: 0\n        int_val: 0\n        int_val: 255\n      }\n    }\n  }\n  attr {\n    key: &quot;max_images&quot;\n    value {\n      i: 10\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weights/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\005\\000\\000\\000\\005\\000\\000\\000\\001\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weights/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weights/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n     ...

# %%
n_iter = 10000
batch_size = 50

logs_list = ["logs_bn", "logs_2"]

for log_dir in logs_list: 
    if tf.gfile.Exists(log_dir):
        tf.gfile.DeleteRecursively(log_dir)
    tf.gfile.MakeDirs(log_dir)

# %%
  
for kind, log_dir in enumerate(logs_list):  
    
    
    res = build_graph(kind==0)
    
    with tf.Session(graph=res["g"]) as sess:
        sess.run(tf.global_variables_initializer())
        opt = res["opt"]
        x = res["x"]
        y_ = res["y"]
        loss = res["loss"]
        accuracy = res["acc"]
        keep_prob =res["keep_prob"]
    
    
    
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
        test_writer = tf.summary.FileWriter(log_dir + '/test')
    
        for i in tqdm(range(n_iter)):
            batch = mnist.train.next_batch(batch_size)
            _ = sess.run(opt, feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.6})
        
            if i % 100 == 0 and i != 0:
                train_loss, train_accuracy, summary = sess.run([loss, accuracy, merged], feed_dict={
                      x: batch[0], y_: batch[1], keep_prob: 1.0})
                print('step %d, training loss %g, training accuracy %g' % (i, train_loss, train_accuracy))
                train_writer.add_summary(summary, i)
        
        test_accuracy, test_summary, = sess.run([accuracy, merged], 
                                           feed_dict={x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0})
        #train_writer.add_summary(test_summary, 0)
        print('test accuracy %g' % test_accuracy)
# Out:
# A Jupyter Widget
# step 100, training loss 0.399666, training accuracy 0.78
# step 200, training loss 0.500834, training accuracy 0.82
# step 300, training loss 0.446763, training accuracy 0.84
# step 400, training loss 0.333532, training accuracy 0.94
# step 500, training loss 0.29563, training accuracy 0.9
# step 600, training loss 0.408359, training accuracy 0.8
# step 700, training loss 0.465024, training accuracy 0.74
# step 800, training loss 0.551495, training accuracy 0.82
# step 900, training loss 0.538863, training accuracy 0.78
# step 1000, training loss 0.259522, training accuracy 0.88
# step 1100, training loss 0.409668, training accuracy 0.88
# step 1200, training loss 0.223621, training accuracy 0.9
# step 1300, training loss 0.40031, training accuracy 0.82
# step 1400, training loss 0.317953, training accuracy 0.94
# step 1500, training loss 0.424634, training accuracy 0.82
# step 1600, training loss 0.304356, training accuracy 0.88
# step 1700, training loss 0.286663, training accuracy 0.92
# step 1800, training loss 0.528955, training accuracy 0.78
# step 1900, training loss 0.268474, training accuracy 0.88
# step 2000, training loss 0.209214, training accuracy 0.9
# step 2100, training loss 0.291605, training accuracy 0.92
# step 2200, training loss 0.467478, training accuracy 0.82
# step 2300, training loss 0.189355, training accuracy 0.94
# step 2400, training loss 0.295018, training accuracy 0.9
# step 2500, training loss 0.506829, training accuracy 0.76
# step 2600, training loss 0.32889, training accuracy 0.86
# step 2700, training loss 0.538848, training accuracy 0.86
# step 2800, training loss 0.509077, training accuracy 0.8
# step 2900, training loss 0.254277, training accuracy 0.88
# step 3000, training loss 0.167377, training accuracy 0.94
# step 3100, training loss 0.275554, training accuracy 0.86
# step 3200, training loss 0.180026, training accuracy 0.94
# step 3300, training loss 0.207633, training accuracy 0.9
# step 3400, training loss 0.237281, training accuracy 0.92
# step 3500, training loss 0.199234, training accuracy 0.92
# step 3600, training loss 0.326122, training accuracy 0.9
# step 3700, training loss 0.2658, training accuracy 0.9
# step 3800, training loss 0.489241, training accuracy 0.84
# step 3900, training loss 0.564409, training accuracy 0.78
# step 4000, training loss 0.360262, training accuracy 0.88
# step 4100, training loss 0.134541, training accuracy 0.96
# step 4200, training loss 0.200377, training accuracy 0.92
# step 4300, training loss 0.421172, training accuracy 0.86
# step 4400, training loss 0.244002, training accuracy 0.9
# step 4500, training loss 0.198992, training accuracy 0.94
# step 4600, training loss 0.269001, training accuracy 0.92
# step 4700, training loss 0.267347, training accuracy 0.9
# step 4800, training loss 0.339689, training accuracy 0.86
# step 4900, training loss 0.339417, training accuracy 0.86
# step 5000, training loss 0.23821, training accuracy 0.9
# step 5100, training loss 0.177274, training accuracy 0.92
# step 5200, training loss 0.186396, training accuracy 0.94
# step 5300, training loss 0.326765, training accuracy 0.88
# step 5400, training loss 0.368813, training accuracy 0.82
# step 5500, training loss 0.165946, training accuracy 0.92
# step 5600, training loss 0.187883, training accuracy 0.94
# step 5700, training loss 0.0963927, training accuracy 0.98
# step 5800, training loss 0.170607, training accuracy 0.92
# step 5900, training loss 0.173518, training accuracy 0.92
# step 6000, training loss 0.188251, training accuracy 0.92
# step 6100, training loss 0.184405, training accuracy 0.92
# step 6200, training loss 0.185651, training accuracy 0.98
# step 6300, training loss 0.306641, training accuracy 0.88
# step 6400, training loss 0.175174, training accuracy 0.9
# step 6500, training loss 0.207587, training accuracy 0.9
# step 6600, training loss 0.265616, training accuracy 0.9
# step 6700, training loss 0.347014, training accuracy 0.82
# step 6800, training loss 0.239294, training accuracy 0.9
# step 6900, training loss 0.285401, training accuracy 0.86
# step 7000, training loss 0.365177, training accuracy 0.88
# step 7100, training loss 0.0581106, training accuracy 0.98
# step 7200, training loss 0.192345, training accuracy 0.94
# step 7300, training loss 0.387903, training accuracy 0.8
# step 7400, training loss 0.214146, training accuracy 0.86
# step 7500, training loss 0.264399, training accuracy 0.86
# step 7600, training loss 0.090674, training accuracy 0.98
# step 7700, training loss 0.203485, training accuracy 0.9
# step 7800, training loss 0.165236, training accuracy 0.92
# step 7900, training loss 0.320616, training accuracy 0.88
# step 8000, training loss 0.138931, training accuracy 0.94
# step 8100, training loss 0.180714, training accuracy 0.88
# step 8200, training loss 0.377361, training accuracy 0.88
# step 8300, training loss 0.141491, training accuracy 0.96
# step 8400, training loss 0.204119, training accuracy 0.92
# step 8500, training loss 0.22353, training accuracy 0.94
# step 8600, training loss 0.115578, training accuracy 0.96
# step 8700, training loss 0.266255, training accuracy 0.9
# step 8800, training loss 0.182227, training accuracy 0.92
# step 8900, training loss 0.131422, training accuracy 0.96
# step 9000, training loss 0.1273, training accuracy 0.94
# step 9100, training loss 0.155796, training accuracy 0.94
# step 9200, training loss 0.0933009, training accuracy 0.98
# step 9300, training loss 0.242631, training accuracy 0.9
# step 9400, training loss 0.18713, training accuracy 0.92
# step 9500, training loss 0.185934, training accuracy 0.94
# step 9600, training loss 0.309514, training accuracy 0.86
# step 9700, training loss 0.122387, training accuracy 0.94
# step 9800, training loss 0.206623, training accuracy 0.92
# step 9900, training loss 0.090965, training accuracy 0.98
#
# test accuracy 0.9136
# A Jupyter Widget
# step 100, training loss 0.598225, training accuracy 0.78
# step 200, training loss 0.43543, training accuracy 0.86
# step 300, training loss 0.270547, training accuracy 0.88
# step 400, training loss 0.593849, training accuracy 0.76
# step 500, training loss 0.297397, training accuracy 0.88
# step 600, training loss 0.170153, training accuracy 0.98
# step 700, training loss 0.164027, training accuracy 0.94
# step 800, training loss 0.316051, training accuracy 0.9
# step 900, training loss 0.310851, training accuracy 0.88
# step 1000, training loss 0.234131, training accuracy 0.94
# step 1100, training loss 0.23575, training accuracy 0.9
# step 1200, training loss 0.296663, training accuracy 0.88
# step 1300, training loss 0.194727, training accuracy 0.96
# step 1400, training loss 0.434186, training accuracy 0.82
# step 1500, training loss 0.290158, training accuracy 0.9
# step 1600, training loss 0.219183, training accuracy 0.94
# step 1700, training loss 0.30341, training accuracy 0.94
# step 1800, training loss 0.167916, training accuracy 0.94
# step 1900, training loss 0.448353, training accuracy 0.84
# step 2000, training loss 0.189558, training accuracy 0.9
# step 2100, training loss 0.203497, training accuracy 0.92
# step 2200, training loss 0.307746, training accuracy 0.84
# step 2300, training loss 0.250879, training accuracy 0.92
# step 2400, training loss 0.190112, training accuracy 0.92
# step 2500, training loss 0.351171, training accuracy 0.86
# step 2600, training loss 0.297065, training accuracy 0.9
# step 2700, training loss 0.129858, training accuracy 0.96
# step 2800, training loss 0.305236, training accuracy 0.82
# step 2900, training loss 0.268014, training accuracy 0.88
# step 3000, training loss 0.24595, training accuracy 0.88
# step 3100, training loss 0.322705, training accuracy 0.88
# step 3200, training loss 0.0652995, training accuracy 1
# step 3300, training loss 0.269871, training accuracy 0.94
# step 3400, training loss 0.226221, training accuracy 0.9
# step 3500, training loss 0.151817, training accuracy 0.94
# step 3600, training loss 0.248781, training accuracy 0.9
# step 3700, training loss 0.231622, training accuracy 0.9
# step 3800, training loss 0.11105, training accuracy 0.98
# step 3900, training loss 0.121814, training accuracy 0.96
# step 4000, training loss 0.169582, training accuracy 0.92
# step 4100, training loss 0.107574, training accuracy 0.94
# step 4200, training loss 0.146355, training accuracy 0.9
# step 4300, training loss 0.212682, training accuracy 0.9
# step 4400, training loss 0.127915, training accuracy 0.96
# step 4500, training loss 0.341415, training accuracy 0.86
# step 4600, training loss 0.176196, training accuracy 0.96
# step 4700, training loss 0.149025, training accuracy 0.96
# step 4800, training loss 0.154848, training accuracy 0.92
# step 4900, training loss 0.174403, training accuracy 0.96
# step 5000, training loss 0.231333, training accuracy 0.9
# step 5100, training loss 0.0584927, training accuracy 0.98
# step 5200, training loss 0.216771, training accuracy 0.9
# step 5300, training loss 0.114281, training accuracy 0.94
# step 5400, training loss 0.0995122, training accuracy 0.96
# step 5500, training loss 0.0457916, training accuracy 1
# step 5600, training loss 0.0802836, training accuracy 0.98
# step 5700, training loss 0.0635427, training accuracy 0.98
# step 5800, training loss 0.0674096, training accuracy 0.98
# step 5900, training loss 0.183145, training accuracy 0.94
# step 6000, training loss 0.0625238, training accuracy 0.98
# step 6100, training loss 0.11945, training accuracy 0.94
# step 6200, training loss 0.108353, training accuracy 0.94
# step 6300, training loss 0.154771, training accuracy 0.94
# step 6400, training loss 0.0456257, training accuracy 1
# step 6500, training loss 0.166697, training accuracy 0.94
# step 6600, training loss 0.158155, training accuracy 0.94
# step 6700, training loss 0.0662973, training accuracy 0.96
# step 6800, training loss 0.160157, training accuracy 0.92
# step 6900, training loss 0.108282, training accuracy 0.94
# step 7000, training loss 0.116013, training accuracy 0.94
# step 7100, training loss 0.148108, training accuracy 0.94
# step 7200, training loss 0.0762684, training accuracy 0.98
# step 7300, training loss 0.123202, training accuracy 0.98
# step 7400, training loss 0.115216, training accuracy 0.98
# step 7500, training loss 0.0529402, training accuracy 0.98
# step 7600, training loss 0.0700027, training accuracy 0.96
# step 7700, training loss 0.173657, training accuracy 0.88
# step 7800, training loss 0.0726357, training accuracy 0.96
# step 7900, training loss 0.222789, training accuracy 0.92
# step 8000, training loss 0.0847201, training accuracy 0.98
# step 8100, training loss 0.127409, training accuracy 0.94
# step 8200, training loss 0.0382954, training accuracy 0.98
# step 8300, training loss 0.0616123, training accuracy 1
# step 8400, training loss 0.0330049, training accuracy 1
# step 8500, training loss 0.206403, training accuracy 0.92
# step 8600, training loss 0.13575, training accuracy 0.94

# %% [markdown]
# ```
# tensorboard --logdir=bn:logs_bn,no_bn:logs_2
# ```
