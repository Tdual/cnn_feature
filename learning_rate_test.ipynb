# %% [markdown]
# downlaod from fashion MNIST
# ```
# wget http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# wget http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# wget http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# wget http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# ```
# put them into data/fashion

# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy import misc
from tqdm import tqdm_notebook as tqdm
# %matplotlib inline

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('./data/fashion', one_hot=True)
# Out:
# Extracting ./data/fashion/train-images-idx3-ubyte.gz
# Extracting ./data/fashion/train-labels-idx1-ubyte.gz
# Extracting ./data/fashion/t10k-images-idx3-ubyte.gz
# Extracting ./data/fashion/t10k-labels-idx1-ubyte.gz

# %%
img, label = mnist.train.next_batch(10)

# %%
dim = 28
fig, axs = plt.subplots(1, len(img), figsize=(20, 3))
for i, m in enumerate(img):
        axs[i].imshow(np.reshape(m, (dim, dim)),cmap='gray')
        axs[i].axis('off')
plt.show()

# %%
def weight_variable(shape):
    w = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(w)

def bias_variable(shape):
    b = tf.constant(0.1, shape=shape)
    return tf.Variable(b)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1,1,1,1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

def variable_summaries(var):  
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)

# %%
def build_graph(kind=0):
    height = 28
    width = 28
    image_size = height * width

    tf.reset_default_graph()
    with tf.Graph().as_default() as g1:
        with tf.name_scope('input'):
            x = tf.placeholder(tf.float32, shape=[None, image_size], name='x-input')
            y_ = tf.placeholder(tf.float32, shape=[None, 10], name='y-input')
            keep_prob = tf.placeholder(tf.float32, name="dropout-input")

        with tf.name_scope('input_reshape'):    
            x_image = tf.reshape(x, [-1, height, width, 1])
            tf.summary.image('input',  x_image, 10)

        with tf.name_scope("conv1"):
            with tf.name_scope('weights'):
                W_conv1 = weight_variable([5,5,1,32])
                variable_summaries(W_conv1)        
            with tf.name_scope('biases'):
                b_conv1 = bias_variable([32])
                variable_summaries(b_conv1)
            h_conv1 = conv2d(x_image, W_conv1) + b_conv1
            variable_summaries(h_conv1)
        
        #with tf.name_scope("batch_norm")
        #    h_conv1_bn = tf.nn.batch_normalizasion(h_conv1, )

        with tf.name_scope("relu1"):
            h_conv1_act = tf.nn.relu(h_conv1)

        with tf.name_scope("pool1"):   
            h_pool1 = max_pool_2x2(h_conv1_act)
            variable_summaries(h_pool1)

        with tf.name_scope("conv2"):
            with tf.name_scope('weights'):
                W_conv2 = weight_variable([5,5,32,64])
                variable_summaries(W_conv2) 
            with tf.name_scope('biases'):    
                b_conv2 = bias_variable([64])
                variable_summaries(b_conv2)
            h_conv2 = conv2d(h_pool1, W_conv2) + b_conv2
            variable_summaries(h_conv2)

        with tf.name_scope("relu2"):
            h_conv2_act = tf.nn.relu(h_conv2)

        with tf.name_scope("pool2"):
            h_pool2 = max_pool_2x2(h_conv2_act)
            variable_summaries(h_pool2)

        with tf.name_scope("pool2_flat"):
            h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])

        with tf.name_scope("fc1"):
            with tf.name_scope('weights'):
                W_fc1 = weight_variable([7 * 7 * 64, 1024])
            with tf.name_scope('biases'):   
                b_fc1 = bias_variable([1024])
            h_fc1 =tf.matmul(h_pool2_flat, W_fc1) + b_fc1

        with tf.name_scope("relu3"):
            h_fc1_act = tf.nn.relu(h_fc1)

        with tf.name_scope("dropout"):
            h_fc1_drop = tf.nn.dropout(h_fc1_act, keep_prob)

        with tf.name_scope("fc2"):
            with tf.name_scope('weights'):
                W_fc2 = weight_variable([1024,10])
            with tf.name_scope('biases'): 
                b_fc2 = bias_variable([10]) 
            y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

        with tf.name_scope("loss"):
            loss = tf.reduce_mean(
                tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
            tf.summary.scalar('cross_entropy', loss)
            
        if kind == 0:
            with tf.name_scope("optimizer"):
                opt = tf.train.AdamOptimizer(1e-2).minimize(loss)
        elif kind == 1:
            with tf.name_scope("optimizer_1"):
                opt = tf.train.AdamOptimizer(1e-3).minimize(loss)
        elif kind == 2:
            with tf.name_scope("optimizer_2"):
                opt = tf.train.AdamOptimizer(1e-4).minimize(loss)
        elif kind == 3:
            with tf.name_scope("optimizer_2"):
                opt = tf.train.AdamOptimizer(1e-5).minimize(loss)

        with tf.name_scope("accuracy"):
            correct = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
            accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
            tf.summary.scalar('accuracy', accuracy)
    
    res = {
        "g": g1,
        "x": x,
        "y": y_,
        "keep_prob": keep_prob,
        "loss": loss,
        "acc": accuracy,
        "opt": opt
    }
    return res

# %%
g = build_graph(0)["g"]
import tensorboard as tb 
tb.show_graph(g)
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.4023895050159746&quot;).pbtxt = 'node {\n  name: &quot;input/x-input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 784\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input/y-input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 10\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input/dropout-input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input_reshape/Reshape/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\377\\377\\377\\377\\034\\000\\000\\000\\034\\000\\000\\000\\001\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input_reshape/Reshape&quot;\n  op: &quot;Reshape&quot;\n  input: &quot;input/x-input&quot;\n  input: &quot;input_reshape/Reshape/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;Tshape&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;input_reshape/input/tag&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_STRING\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_STRING\n        tensor_shape {\n        }\n        string_val: &quot;input_reshape/input&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;input_reshape/input&quot;\n  op: &quot;ImageSummary&quot;\n  input: &quot;input_reshape/input/tag&quot;\n  input: &quot;input_reshape/Reshape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;bad_color&quot;\n    value {\n      tensor {\n        dtype: DT_UINT8\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        int_val: 255\n        int_val: 0\n        int_val: 0\n        int_val: 255\n      }\n    }\n  }\n  attr {\n    key: &quot;max_images&quot;\n    value {\n      i: 10\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weights/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\005\\000\\000\\000\\005\\000\\000\\000\\001\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weights/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/weights/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n     ...

# %%
n_iter = 10000
batch_size = 50

logs_list = ["logs", "logs_1",  "logs_2", "logs_3"]

for log_dir in logs_list: 
    if tf.gfile.Exists(log_dir):
        tf.gfile.DeleteRecursively(log_dir)
    tf.gfile.MakeDirs(log_dir)
    
for kind, log_dir in enumerate(logs_list):  
    
    res = build_graph(kind)
    
    with tf.Session(graph=res["g"]) as sess:
        sess.run(tf.global_variables_initializer())
        opt = res["opt"]
        x = res["x"]
        y_ = res["y"]
        loss = res["loss"]
        accuracy = res["acc"]
        keep_prob =res["keep_prob"]
    
    
    
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
        test_writer = tf.summary.FileWriter(log_dir + '/test')
    
        for i in tqdm(range(n_iter)):
            batch = mnist.train.next_batch(batch_size)
            _ = sess.run(opt, feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.6})
        
            if i % 100 == 0 and i != 0:
                train_loss, train_accuracy, summary = sess.run([loss, accuracy, merged], feed_dict={
                      x: batch[0], y_: batch[1], keep_prob: 1.0})
                print('step %d, training loss %g, training accuracy %g' % (i, train_loss, train_accuracy))
                train_writer.add_summary(summary, i)
        
        test_accuracy, test_summary, = sess.run([accuracy, merged], 
                                           feed_dict={x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0})
        #test_writer.add_summary(test_summary, 0)
        print('test accuracy %g' % test_accuracy)
# Out:
# A Jupyter Widget
# step 100, training loss 0.749163, training accuracy 0.68
# step 200, training loss 0.626337, training accuracy 0.76
# step 300, training loss 0.455524, training accuracy 0.8
# step 400, training loss 0.411109, training accuracy 0.8
# step 500, training loss 0.185982, training accuracy 0.96
# step 600, training loss 0.256409, training accuracy 0.94
# step 700, training loss 0.210516, training accuracy 0.94
# step 800, training loss 0.564184, training accuracy 0.8
# step 900, training loss 0.457765, training accuracy 0.8
# step 1000, training loss 0.318523, training accuracy 0.88
# step 1100, training loss 0.445605, training accuracy 0.86
# step 1200, training loss 0.45345, training accuracy 0.9
# step 1300, training loss 0.349217, training accuracy 0.9
# step 1400, training loss 0.382784, training accuracy 0.86
# step 1500, training loss 0.432574, training accuracy 0.82
# step 1600, training loss 0.41557, training accuracy 0.84
# step 1700, training loss 0.319478, training accuracy 0.88
# step 1800, training loss 0.452596, training accuracy 0.82
# step 1900, training loss 0.273474, training accuracy 0.9
# step 2000, training loss 0.424441, training accuracy 0.82
# step 2100, training loss 0.434686, training accuracy 0.86
# step 2200, training loss 0.332877, training accuracy 0.88
# step 2300, training loss 0.526204, training accuracy 0.84
# step 2400, training loss 0.242332, training accuracy 0.92
# step 2500, training loss 0.140317, training accuracy 0.94
# step 2600, training loss 0.32184, training accuracy 0.9
# step 2700, training loss 0.434711, training accuracy 0.74
# step 2800, training loss 0.18539, training accuracy 0.94
# step 2900, training loss 0.296842, training accuracy 0.8
# step 3000, training loss 0.488405, training accuracy 0.78
# step 3100, training loss 0.391377, training accuracy 0.84
# step 3200, training loss 0.225665, training accuracy 0.86
# step 3300, training loss 0.288838, training accuracy 0.9
# step 3400, training loss 0.500898, training accuracy 0.76
# step 3500, training loss 0.288646, training accuracy 0.88
# step 3600, training loss 0.369829, training accuracy 0.86
# step 3700, training loss 0.320625, training accuracy 0.88
# step 3800, training loss 0.253874, training accuracy 0.92
# step 3900, training loss 0.131727, training accuracy 0.96
# step 4000, training loss 0.340663, training accuracy 0.88
# step 4100, training loss 0.322699, training accuracy 0.88
# step 4200, training loss 0.329552, training accuracy 0.88
# step 4300, training loss 0.240247, training accuracy 0.92
# step 4400, training loss 0.331546, training accuracy 0.84
# step 4500, training loss 0.397817, training accuracy 0.82
# step 4600, training loss 0.199608, training accuracy 0.96
# step 4700, training loss 0.398194, training accuracy 0.86
# step 4800, training loss 0.392731, training accuracy 0.86
# step 4900, training loss 0.488351, training accuracy 0.86
# step 5000, training loss 0.27167, training accuracy 0.86
# step 5100, training loss 0.242984, training accuracy 0.94
# step 5200, training loss 0.559932, training accuracy 0.82
# step 5300, training loss 0.138545, training accuracy 0.96
# step 5400, training loss 0.146461, training accuracy 0.9
# step 5500, training loss 0.27714, training accuracy 0.86
# step 5600, training loss 0.25486, training accuracy 0.9
# step 5700, training loss 0.501799, training accuracy 0.74
# step 5800, training loss 0.252687, training accuracy 0.9
# step 5900, training loss 0.174548, training accuracy 0.94
# step 6000, training loss 0.237337, training accuracy 0.88
# step 6100, training loss 0.328251, training accuracy 0.88
# step 6200, training loss 0.542313, training accuracy 0.86
# step 6300, training loss 0.289489, training accuracy 0.88
# step 6400, training loss 0.191869, training accuracy 0.94
# step 6500, training loss 0.469105, training accuracy 0.84
# step 6600, training loss 0.366223, training accuracy 0.9
# step 6700, training loss 0.400897, training accuracy 0.84
# step 6800, training loss 0.108686, training accuracy 0.96
# step 6900, training loss 0.331286, training accuracy 0.9
# step 7000, training loss 0.337443, training accuracy 0.88
# step 7100, training loss 0.206655, training accuracy 0.94
# step 7200, training loss 0.224177, training accuracy 0.92
# step 7300, training loss 0.230346, training accuracy 0.9
# step 7400, training loss 0.371305, training accuracy 0.84
# step 7500, training loss 0.336363, training accuracy 0.9
# step 7600, training loss 0.282782, training accuracy 0.88
# step 7700, training loss 0.328663, training accuracy 0.86
# step 7800, training loss 0.467204, training accuracy 0.88
# step 7900, training loss 0.195097, training accuracy 0.9
# step 8000, training loss 0.419281, training accuracy 0.8
# step 8100, training loss 0.271113, training accuracy 0.88
# step 8200, training loss 0.213807, training accuracy 0.92
# step 8300, training loss 0.198972, training accuracy 0.92
# step 8400, training loss 0.416243, training accuracy 0.84
# step 8500, training loss 0.294333, training accuracy 0.86
# step 8600, training loss 0.313133, training accuracy 0.9
# step 8700, training loss 0.130146, training accuracy 0.94
# step 8800, training loss 0.202611, training accuracy 0.92
# step 8900, training loss 0.299659, training accuracy 0.88
# step 9000, training loss 0.408544, training accuracy 0.88
# step 9100, training loss 0.622719, training accuracy 0.8
# step 9200, training loss 0.154628, training accuracy 0.94
# step 9300, training loss 0.3162, training accuracy 0.86
# step 9400, training loss 0.342438, training accuracy 0.86
# step 9500, training loss 0.301303, training accuracy 0.86
# step 9600, training loss 0.262311, training accuracy 0.88
# step 9700, training loss 0.286625, training accuracy 0.84
# step 9800, training loss 0.433059, training accuracy 0.9
# step 9900, training loss 0.233035, training accuracy 0.92
#
# test accuracy 0.8684
# A Jupyter Widget
# step 100, training loss 0.303556, training accuracy 0.92
# step 200, training loss 0.471796, training accuracy 0.82
# step 300, training loss 0.424174, training accuracy 0.84
# step 400, training loss 0.302072, training accuracy 0.9
# step 500, training loss 0.467213, training accuracy 0.8
# step 600, training loss 0.261658, training accuracy 0.94
# step 700, training loss 0.276629, training accuracy 0.92
# step 800, training loss 0.228603, training accuracy 0.92
# step 900, training loss 0.343193, training accuracy 0.86
# step 1000, training loss 0.44433, training accuracy 0.84
# step 1100, training loss 0.273623, training accuracy 0.86
# step 1200, training loss 0.298671, training accuracy 0.96
# step 1300, training loss 0.325948, training accuracy 0.9
# step 1400, training loss 0.191653, training accuracy 0.9
# step 1500, training loss 0.384013, training accuracy 0.86
# step 1600, training loss 0.214218, training accuracy 0.88
# step 1700, training loss 0.348311, training accuracy 0.84
# step 1800, training loss 0.197852, training accuracy 0.94
# step 1900, training loss 0.269991, training accuracy 0.9
# step 2000, training loss 0.135921, training accuracy 0.98
# step 2100, training loss 0.199449, training accuracy 0.92
# step 2200, training loss 0.0861515, training accuracy 1
# step 2300, training loss 0.142929, training accuracy 0.94
# step 2400, training loss 0.27931, training accuracy 0.88
# step 2500, training loss 0.150195, training accuracy 0.92
# step 2600, training loss 0.249146, training accuracy 0.9
# step 2700, training loss 0.213188, training accuracy 0.9
# step 2800, training loss 0.136021, training accuracy 0.98
# step 2900, training loss 0.111801, training accuracy 0.96
# step 3000, training loss 0.114122, training accuracy 0.96
# step 3100, training loss 0.0741678, training accuracy 0.96
# step 3200, training loss 0.262361, training accuracy 0.92
# step 3300, training loss 0.409395, training accuracy 0.84
# step 3400, training loss 0.125046, training accuracy 0.98
# step 3500, training loss 0.154285, training accuracy 0.96
# step 3600, training loss 0.138784, training accuracy 0.96
# step 3700, training loss 0.21459, training accuracy 0.92
# step 3800, training loss 0.106189, training accuracy 0.98
# step 3900, training loss 0.268643, training accuracy 0.94
# step 4000, training loss 0.073158, training accuracy 0.98
# step 4100, training loss 0.136674, training accuracy 0.96
# step 4200, training loss 0.161264, training accuracy 0.94
# step 4300, training loss 0.153651, training accuracy 0.96
# step 4400, training loss 0.11881, training accuracy 0.96
# step 4500, training loss 0.143512, training accuracy 0.92
# step 4600, training loss 0.122143, training accuracy 0.98
# step 4700, training loss 0.245546, training accuracy 0.9
# step 4800, training loss 0.0802037, training accuracy 0.98
# step 4900, training loss 0.150022, training accuracy 0.94
# step 5000, training loss 0.146392, training accuracy 0.94
# step 5100, training loss 0.1297, training accuracy 0.98
# step 5200, training loss 0.106605, training accuracy 0.96
# step 5300, training loss 0.23272, training accuracy 0.9
# step 5400, training loss 0.175894, training accuracy 0.92
# step 5500, training loss 0.152436, training accuracy 0.9
# step 5600, training loss 0.0688944, training accuracy 0.98
# step 5700, training loss 0.0883957, training accuracy 0.98
# step 5800, training loss 0.15486, training accuracy 0.94
# step 5900, training loss 0.267748, training accuracy 0.92
# step 6000, training loss 0.0480485, training accuracy 0.98
# step 6100, training loss 0.0529173, training accuracy 0.98
# step 6200, training loss 0.0196276, training accuracy 1
# step 6300, training loss 0.185567, training accuracy 0.92
# step 6400, training loss 0.065299, training accuracy 1
# step 6500, training loss 0.274942, training accuracy 0.9
# step 6600, training loss 0.116607, training accuracy 0.94
# step 6700, training loss 0.0998297, training accuracy 0.94
# step 6800, training loss 0.115219, training accuracy 0.94
# step 6900, training loss 0.124053, training accuracy 0.98
# step 7000, training loss 0.0672866, training accuracy 0.98
# step 7100, training loss 0.0746611, training accuracy 0.98
# step 7200, training loss 0.127686, training accuracy 0.96
# step 7300, training loss 0.0230592, training accuracy 1
# step 7400, training loss 0.0646704, training accuracy 0.98
# step 7500, training loss 0.090886, training accuracy 0.98
# step 7600, training loss 0.0765497, training accuracy 0.98
# step 7700, training loss 0.0812572, training accuracy 0.98
# step 7800, training loss 0.0800326, training accuracy 0.98
# step 7900, training loss 0.0981242, training accuracy 0.92
# step 8000, training loss 0.104254, training accuracy 0.98
# step 8100, training loss 0.0656389, training accuracy 0.96
# step 8200, training loss 0.286344, training accuracy 0.9
# step 8300, training loss 0.0352958, training accuracy 1
# step 8400, training loss 0.128903, training accuracy 0.96
# step 8500, training loss 0.0541576, training accuracy 0.96
# step 8600, training loss 0.0634277, training accuracy 0.98
# step 8700, training loss 0.0751118, training accuracy 0.98
# step 8800, training loss 0.223974, training accuracy 0.92
# step 8900, training loss 0.106669, training accuracy 0.96
# step 9000, training loss 0.0134047, training accuracy 1
# step 9100, training loss 0.0686234, training accuracy 0.96
# step 9200, training loss 0.0246562, training accuracy 1
# step 9300, training loss 0.0358352, training accuracy 0.98
# step 9400, training loss 0.0214826, training accuracy 1
# step 9500, training loss 0.0548196, training accuracy 0.98
# step 9600, training loss 0.0172525, training accuracy 1
# step 9700, training loss 0.0516377, training accuracy 0.98
# step 9800, training loss 0.0893608, training accuracy 0.98
# step 9900, training loss 0.0204029, training accuracy 1
#
# test accuracy 0.9112
# A Jupyter Widget
# step 100, training loss 0.473574, training accuracy 0.8
# step 200, training loss 0.516258, training accuracy 0.86
# step 300, training loss 0.539672, training accuracy 0.8
# step 400, training loss 0.406226, training accuracy 0.84
# step 500, training loss 0.386561, training accuracy 0.92
# step 600, training loss 0.26996, training accuracy 0.88
# step 700, training loss 0.223868, training accuracy 0.96
# step 800, training loss 0.516049, training accuracy 0.82
# step 900, training loss 0.334494, training accuracy 0.94
# step 1000, training loss 0.59798, training accuracy 0.76
# step 1100, training loss 0.419505, training accuracy 0.82
# step 1200, training loss 0.317054, training accuracy 0.92
# step 1300, training loss 0.414948, training accuracy 0.84
# step 1400, training loss 0.348867, training accuracy 0.82
# step 1500, training loss 0.348604, training accuracy 0.86
# step 1600, training loss 0.42731, training accuracy 0.82
# step 1700, training loss 0.307916, training accuracy 0.9
# step 1800, training loss 0.383304, training accuracy 0.84
# step 1900, training loss 0.237868, training accuracy 0.98
# step 2000, training loss 0.286635, training accuracy 0.86
# step 2100, training loss 0.436721, training accuracy 0.82
# step 2200, training loss 0.206554, training accuracy 0.96
# step 2300, training loss 0.22032, training accuracy 0.94
# step 2400, training loss 0.363958, training accuracy 0.88
# step 2500, training loss 0.155474, training accuracy 0.94
# step 2600, training loss 0.288126, training accuracy 0.94
# step 2700, training loss 0.373559, training accuracy 0.88
# step 2800, training loss 0.14004, training accuracy 0.98
# step 2900, training loss 0.433356, training accuracy 0.84
# step 3000, training loss 0.224401, training accuracy 0.92
# step 3100, training loss 0.150005, training accuracy 0.94
# step 3200, training loss 0.156248, training accuracy 0.94
# step 3300, training loss 0.258891, training accuracy 0.92
# step 3400, training loss 0.179604, training accuracy 0.94
# step 3500, training loss 0.236371, training accuracy 0.92
# step 3600, training loss 0.462513, training accuracy 0.84
# step 3700, training loss 0.350571, training accuracy 0.84
# step 3800, training loss 0.213093, training accuracy 0.92
# step 3900, training loss 0.376567, training accuracy 0.88
# step 4000, training loss 0.36598, training accuracy 0.84
# step 4100, training loss 0.316533, training accuracy 0.9
# step 4200, training loss 0.354198, training accuracy 0.88
# step 4300, training loss 0.150633, training accuracy 0.96
# step 4400, training loss 0.284653, training accuracy 0.9
# step 4500, training loss 0.282921, training accuracy 0.88
# step 4600, training loss 0.231427, training accuracy 0.88
# step 4700, training loss 0.250791, training accuracy 0.92
# step 4800, training loss 0.381141, training accuracy 0.86
# step 4900, training loss 0.163138, training accuracy 0.96
# step 5000, training loss 0.290914, training accuracy 0.86
# step 5100, training loss 0.182701, training accuracy 0.94
# step 5200, training loss 0.360634, training accuracy 0.84
# step 5300, training loss 0.136293, training accuracy 0.96
# step 5400, training loss 0.199673, training accuracy 0.94
# step 5500, training loss 0.219827, training accuracy 0.9
# step 5600, training loss 0.19993, training accuracy 0.92
# step 5700, training loss 0.371634, training accuracy 0.82
# step 5800, training loss 0.220008, training accuracy 0.9
# step 5900, training loss 0.238189, training accuracy 0.9
# step 6000, training loss 0.216111, training accuracy 0.92
# step 6100, training loss 0.154293, training accuracy 0.96
# step 6200, training loss 0.196183, training accuracy 0.96
# step 6300, training loss 0.214657, training accuracy 0.9
# step 6400, training loss 0.289398, training accuracy 0.92
# step 6500, training loss 0.126384, training accuracy 0.96
# step 6600, training loss 0.256515, training accuracy 0.9
# step 6700, training loss 0.148027, training accuracy 0.96
# step 6800, training loss 0.160777, training accuracy 0.94
# step 6900, training loss 0.277694, training accuracy 0.86
# step 7000, training loss 0.387329, training accuracy 0.82
# step 7100, training loss 0.170464, training accuracy 0.92
# step 7200, training loss 0.180891, training accuracy 0.92
# step 7300, training loss 0.177644, training accuracy 0.94
# step 7400, training loss 0.26951, training accuracy 0.92
# step 7500, training loss 0.0751929, training accuracy 1
# step 7600, training loss 0.191064, training accuracy 0.96
# step 7700, training loss 0.126848, training accuracy 0.96
# step 7800, training loss 0.206233, training accuracy 0.94
# step 7900, training loss 0.097439, training accuracy 0.98
# step 8000, training loss 0.200513, training accuracy 0.92
# step 8100, training loss 0.15063, training accuracy 0.96
# step 8200, training loss 0.195775, training accuracy 0.94
# step 8300, training loss 0.156553, training accuracy 0.94
# step 8400, training loss 0.111972, training accuracy 0.96
# step 8500, training loss 0.2266, training accuracy 0.92
# step 8600, training loss 0.0841426, training accuracy 0.98
# step 8700, training loss 0.104017, training accuracy 0.96
# step 8800, training loss 0.229188, training accuracy 0.88
# step 8900, training loss 0.272318, training accuracy 0.92
# step 9000, training loss 0.248346, training accuracy 0.92
# step 9100, training loss 0.169394, training accuracy 0.94
# step 9200, training loss 0.179111, training accuracy 0.94
# step 9300, training loss 0.138836, training accuracy 0.94
# step 9400, training loss 0.171801, training accuracy 0.94
# step 9500, training loss 0.0773401, training accuracy 0.98
# step 9600, training loss 0.169756, training accuracy 0.94
# step 9700, training loss 0.189289, training accuracy 0.92
# step 9800, training loss 0.110519, training accuracy 0.96
# step 9900, training loss 0.217139, training accuracy 0.88
#
# test accuracy 0.9037
# A Jupyter Widget
# step 100, training loss 1.82986, training accuracy 0.36
# step 200, training loss 0.886982, training accuracy 0.66
# step 300, training loss 1.12198, training accuracy 0.62
# step 400, training loss 0.873085, training accuracy 0.72
# step 500, training loss 0.448034, training accuracy 0.88
# step 600, training loss 0.638214, training accuracy 0.76
# step 700, training loss 0.974863, training accuracy 0.72
# step 800, training loss 0.580869, training accuracy 0.72
# step 900, training loss 0.665633, training accuracy 0.78
# step 1000, training loss 0.574368, training accuracy 0.82
# step 1100, training loss 0.573478, training accuracy 0.78
# step 1200, training loss 0.472974, training accuracy 0.82
# step 1300, training loss 0.575484, training accuracy 0.82
# step 1400, training loss 0.53429, training accuracy 0.8
# step 1500, training loss 0.76456, training accuracy 0.64
# step 1600, training loss 0.632586, training accuracy 0.76
# step 1700, training loss 0.511487, training accuracy 0.8
# step 1800, training loss 0.521403, training accuracy 0.82
# step 1900, training loss 0.627912, training accuracy 0.84
# step 2000, training loss 0.612885, training accuracy 0.78
# step 2100, training loss 0.620522, training accuracy 0.78
# step 2200, training loss 0.468142, training accuracy 0.84
# step 2300, training loss 0.354349, training accuracy 0.9
# step 2400, training loss 0.455903, training accuracy 0.84
# step 2500, training loss 0.618508, training accuracy 0.78
# step 2600, training loss 0.439696, training accuracy 0.86
# step 2700, training loss 0.639344, training accuracy 0.76
# step 2800, training loss 0.533534, training accuracy 0.84
# step 2900, training loss 0.534119, training accuracy 0.82
# step 3000, training loss 0.383545, training accuracy 0.86
# step 3100, training loss 0.534228, training accuracy 0.84
# step 3200, training loss 0.494221, training accuracy 0.8
# step 3300, training loss 0.628312, training accuracy 0.82
# step 3400, training loss 0.543168, training accuracy 0.88
# step 3500, training loss 0.534024, training accuracy 0.82
# step 3600, training loss 0.338814, training accuracy 0.82
# step 3700, training loss 0.491299, training accuracy 0.78
# step 3800, training loss 0.349739, training accuracy 0.86
# step 3900, training loss 0.519404, training accuracy 0.82
# step 4000, training loss 0.602342, training accuracy 0.82
# step 4100, training loss 0.434001, training accuracy 0.92
# step 4200, training loss 0.479882, training accuracy 0.82
# step 4300, training loss 0.663152, training accuracy 0.74
# step 4400, training loss 0.331116, training accuracy 0.9
# step 4500, training loss 0.320466, training accuracy 0.88
# step 4600, training loss 0.236699, training accuracy 0.9
# step 4700, training loss 0.395491, training accuracy 0.9
# step 4800, training loss 0.500293, training accuracy 0.82
# step 4900, training loss 0.287417, training accuracy 0.92
# step 5000, training loss 0.318466, training accuracy 0.92
# step 5100, training loss 0.541049, training accuracy 0.76
# step 5200, training loss 0.368397, training accuracy 0.88
# step 5300, training loss 0.367788, training accuracy 0.86
# step 5400, training loss 0.210072, training accuracy 0.9
# step 5500, training loss 0.465941, training accuracy 0.8
# step 5600, training loss 0.443225, training accuracy 0.82
# step 5700, training loss 0.337441, training accuracy 0.9
# step 5800, training loss 0.304877, training accuracy 0.86
# step 5900, training loss 0.327873, training accuracy 0.88
# step 6000, training loss 0.393027, training accuracy 0.86
# step 6100, training loss 0.279315, training accuracy 0.9
# step 6200, training loss 0.474227, training accuracy 0.9
# step 6300, training loss 0.297336, training accuracy 0.92
# step 6400, training loss 0.339661, training accuracy 0.88
# step 6500, training loss 0.312522, training accuracy 0.88
# step 6600, training loss 0.489198, training accuracy 0.86
# step 6700, training loss 0.455968, training accuracy 0.88
# step 6800, training loss 0.420292, training accuracy 0.86
# step 6900, training loss 0.347521, training accuracy 0.86
# step 7000, training loss 0.3106, training accuracy 0.88
# step 7100, training loss 0.259994, training accuracy 0.9
# step 7200, training loss 0.482306, training accuracy 0.82
# step 7300, training loss 0.574871, training accuracy 0.78
# step 7400, training loss 0.436056, training accuracy 0.88
# step 7500, training loss 0.370617, training accuracy 0.84
# step 7600, training loss 0.4175, training accuracy 0.84
# step 7700, training loss 0.388368, training accuracy 0.88
# step 7800, training loss 0.27113, training accuracy 0.92
# step 7900, training loss 0.471517, training accuracy 0.82
# step 8000, training loss 0.439673, training accuracy 0.82
# step 8100, training loss 0.497858, training accuracy 0.76
# step 8200, training loss 0.27008, training accuracy 0.9
# step 8300, training loss 0.231328, training accuracy 0.96
# step 8400, training loss 0.329455, training accuracy 0.88
# step 8500, training loss 0.473486, training accuracy 0.76
# step 8600, training loss 0.211286, training accuracy 0.92
# step 8700, training loss 0.431737, training accuracy 0.88
# step 8800, training loss 0.204384, training accuracy 0.94
# step 8900, training loss 0.120514, training accuracy 0.96
# step 9000, training loss 0.350821, training accuracy 0.88
# step 9100, training loss 0.462601, training accuracy 0.86
# step 9200, training loss 0.222599, training accuracy 0.9
# step 9300, training loss 0.380885, training accuracy 0.84
# step 9400, training loss 0.594354, training accuracy 0.82
# step 9500, training loss 0.410698, training accuracy 0.84
# step 9600, training loss 0.37922, training accuracy 0.86
# step 9700, training loss 0.373849, training accuracy 0.84
# step 9800, training loss 0.297373, training accuracy 0.88
# step 9900, training loss 0.376064, training accuracy 0.88
#
# test accuracy 0.8642

# %% [markdown]
# ```
# tensorboard --logdir=2:logs,3:logs_1,4:logs_2,5:logs_3
# ```
